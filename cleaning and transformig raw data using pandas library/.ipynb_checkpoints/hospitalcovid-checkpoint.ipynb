# %%
import pandas as pd

# %%
pd.read_csv("covid-hospitalizations.csv")
# Out:
#          entity  iso_code        date  \
# 0       Algeria       DZA  2020-07-17
# 1       Algeria       DZA  2020-07-17
# 2       Algeria       DZA  2020-07-18
# 3       Algeria       DZA  2020-07-18
# 4       Algeria       DZA  2020-07-20
# ...         ...       ...         ...
# 230519    Wales  OWID_WLS  2023-07-12
# 230520    Wales  OWID_WLS  2023-07-12
# 230521    Wales  OWID_WLS  2023-07-12
# 230522    Wales  OWID_WLS  2023-07-12
# 230523    Wales  OWID_WLS  2023-07-12
#
#                                          indicator    value
# 0                              Daily ICU occupancy   62.000
# 1                  Daily ICU occupancy per million    1.381
# 2                              Daily ICU occupancy   67.000
# 3                  Daily ICU occupancy per million    1.492
# 4                              Daily ICU occupancy   64.000
# ...                                            ...      ...
# 230519             Daily ICU occupancy per million    1.577
# ...

# %%
#1. check types and nulls
pd.read_csv("covid-hospitalizations.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230524 entries, 0 to 230523
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   entity     230524 non-null  object
#  1   iso_code   230524 non-null  object
#  2   date       230524 non-null  object
#  3   indicator  230524 non-null  object
#  4   value      230524 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 8.8+ MB

# %%
# 2.remove duplicates nd check
df =pd.read_csv("covid-hospitalizations.csv")
df
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [entity, iso_code, date, indicator, value]
# Index: []

# %%
#3. change type of date to datetime and set date as index
df=pd.read_csv("covid-hospitalizations.csv")
df['date'] = pd.to_datetime(df['date'],format="%Y-%m-%d")


# another way
df=pd.read_csv("covid-hospitalizations.csv",parse_dates=['date'])
df.info()

#### date as index
df = df.set_index('date')
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230524 entries, 0 to 230523
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   entity     230524 non-null  object
#  1   iso_code   230524 non-null  object
#  2   date       230524 non-null  datetime64[ns]
#  3   indicator  230524 non-null  object
#  4   value      230524 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 8.8+ MB
#              entity  iso_code                                   indicator  \
# date
# 2020-07-17  Algeria       DZA                         Daily ICU occupancy
# 2020-07-17  Algeria       DZA             Daily ICU occupancy per million
# 2020-07-18  Algeria       DZA                         Daily ICU occupancy
# 2020-07-18  Algeria       DZA             Daily ICU occupancy per million
# 2020-07-20  Algeria       DZA                         Daily ICU occupancy
# ...

# %%
# 4. column's case convertion
df.columns = df.columns.str.title()
df
# Out:
#              Entity Iso_Code                                   Indicator  \
# Date
# 2020-01-06   Latvia      LVA  Weekly new hospital admissions per million
# 2020-01-06   Latvia      LVA       Weekly new ICU admissions per million
# 2020-01-06   Latvia      LVA                   Weekly new ICU admissions
# 2020-01-06   Greece      GRC                   Weekly new ICU admissions
# 2020-01-06   Greece      GRC       Weekly new ICU admissions per million
# ...             ...      ...                                         ...
# 2024-08-11  Czechia      CZE        Daily hospital occupancy per million
# 2024-08-12  Czechia      CZE                         Daily ICU occupancy
# 2024-08-12  Czechia      CZE                    Daily hospital occupancy
# 2024-08-12  Czechia      CZE        Daily hospital occupancy per million
# 2024-08-12  Czechia      CZE             Daily ICU occupancy per million
#
#              Value
# Date
# 2020-01-06   0.000
# 2020-01-06   0.000
# ...

# %%
# 5. set index's case
df.index.name = "Date"
df
# Out:
#              Entity Iso_Code                                   Indicator  \
# Date
# 2020-01-06   Latvia      LVA  Weekly new hospital admissions per million
# 2020-01-06   Latvia      LVA       Weekly new ICU admissions per million
# 2020-01-06   Latvia      LVA                   Weekly new ICU admissions
# 2020-01-06   Greece      GRC                   Weekly new ICU admissions
# 2020-01-06   Greece      GRC       Weekly new ICU admissions per million
# ...             ...      ...                                         ...
# 2024-08-11  Czechia      CZE        Daily hospital occupancy per million
# 2024-08-12  Czechia      CZE                         Daily ICU occupancy
# 2024-08-12  Czechia      CZE                    Daily hospital occupancy
# 2024-08-12  Czechia      CZE        Daily hospital occupancy per million
# 2024-08-12  Czechia      CZE             Daily ICU occupancy per million
#
#              Value
# Date
# 2020-01-06   0.000
# 2020-01-06   0.000
# ...

# %%
#6. sort data by date
df = df.sort_index()
df

# same as 
df = df.sort_values(by='Date')
df
# Out:
#              Entity Iso_Code                                   Indicator  \
# Date
# 2020-01-06   Latvia      LVA  Weekly new hospital admissions per million
# 2020-01-06   Latvia      LVA       Weekly new ICU admissions per million
# 2020-01-06   Latvia      LVA                   Weekly new ICU admissions
# 2020-01-06   Greece      GRC                   Weekly new ICU admissions
# 2020-01-06   Greece      GRC       Weekly new ICU admissions per million
# ...             ...      ...                                         ...
# 2024-08-11  Czechia      CZE        Daily hospital occupancy per million
# 2024-08-12  Czechia      CZE        Daily hospital occupancy per million
# 2024-08-12  Czechia      CZE                         Daily ICU occupancy
# 2024-08-12  Czechia      CZE                    Daily hospital occupancy
# 2024-08-12  Czechia      CZE             Daily ICU occupancy per million
#
#              Value
# Date
# 2020-01-06   0.000
# 2020-01-06   0.000
# ...

# %%
# # .check for no duplicates
# df.duplicated().sum()

# # same as with to confirm uniqueness by specific columns:
# df.reset_index().duplicated(subset=['Date', 'Entity', 'Indicator']).sum()
# Out:
# np.int64(0)

# %%
# 7.re-load into excel
# firstly import openpyxl module in environment of anaconda navigator
import openpyxl
# to excel
df.to_excel("hospitalcovid_cleaned.xlsx", index=True)
# (OR)

# to csv
df.to_csv("hospitalcovid_cleaned.csv", index=True)
