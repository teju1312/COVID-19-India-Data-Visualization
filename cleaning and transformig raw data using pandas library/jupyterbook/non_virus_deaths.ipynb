# %%
import pandas as pd

# %%
pd.read_csv("india_non-virus-deaths.csv")
# Out:
#     DB_LASTUPDATED_SET  S. No                     Incident Location  \
# 0          SET_JUNE-13    1.0                                  Agra
# 1          SET_JUNE-13    2.0                             Pandesara
# 2          SET_JUNE-13    3.0                                Jaipur
# 3          SET_JUNE-13    4.0                          Secunderabad
# 4          SET_JUNE-13    5.0  Mountainous peak over Jawahar Tunnel
# ..                 ...    ...                                   ...
# 696        SET_JUNE-13   35.0                               Kalenda
# 697        SET_JUNE-13   36.0                            Gohrapadar
# 698        SET_JUNE-13   37.0                            Jayarampur
# 699        SET_JUNE-13   38.0                              Dehradun
# 700        SET_JUNE-13   39.0                                   NaN
#
#          District           State/UT    Date of incident  No. of deaths  \
# 0            Agra      Uttar Pradesh       March 28,2020            1.0
# ...

# %%
#1. check types and nulls
pd.read_csv("india_non-virus-deaths.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DB_LASTUPDATED_SET   699 non-null    object
#  1   S. No                700 non-null    float64
#  2   Incident Location    556 non-null    object
#  3   District             672 non-null    object
#  4   State/UT             698 non-null    object
#  5   Date of incident     694 non-null    object
#  6   No. of deaths        700 non-null    float64
#  7   Reason of death      700 non-null    object
#  8   Source               700 non-null    object
#  9   Date of publication  699 non-null    object
#  10  Link                 700 non-null    object
#  11  Category             700 non-null    object
#  12  Name(s) and age      697 non-null    object
#  13  Occupation
# Category  687 non-null    object
# dtypes: float64(2), object(12)
# memory usage: 76.8+ KB

# %%
# 2.remove unwanted columns
df = pd.read_csv("india_non-virus-deaths.csv")
df = df.drop(columns=['DB_LASTUPDATED_SET','Source','Date of publication','Link','Category'])
df
# Out:
#      S. No                     Incident Location      District  \
# 0      1.0                                  Agra          Agra
# 1      2.0                             Pandesara         Surat
# 2      3.0                                Jaipur        Jaipur
# 3      4.0                          Secunderabad  Secunderabad
# 4      5.0  Mountainous peak over Jawahar Tunnel      Anantnag
# ..     ...                                   ...           ...
# 696   35.0                               Kalenda    Mahasamund
# 697   36.0                            Gohrapadar     Gariaband
# 698   37.0                            Jayarampur      Balasore
# 699   38.0                              Dehradun      Dehradun
# 700   39.0                                   NaN           NaN
#
#               State/UT    Date of incident  No. of deaths  \
# 0        Uttar Pradesh       March 28,2020            1.0
# 1              Gujarat      March 27, 2020            1.0
# ...

# %%
#3. check count of unique

df.nunique()
# Out:
# S. No                   201
# Incident Location       512
# District                357
# State/UT                 29
# Date of incident        145
# No. of deaths            14
# Reason of death         348
# Name(s) and age         638
# Occupation\nCategory    190
# dtype: int64

# %%
# 4.change types
df['No. of deaths'] = df['No. of deaths'].astype("Int64")
df['S. No'] =df['S. No'].astype("Int64")
df
df.info()
df.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   S. No                700 non-null    Int64
#  1   Incident Location    556 non-null    object
#  2   District             672 non-null    object
#  3   State/UT             698 non-null    object
#  4   Date of incident     694 non-null    object
#  5   No. of deaths        700 non-null    Int64
#  6   Reason of death      700 non-null    object
#  7   Name(s) and age      697 non-null    object
#  8   Occupation
# Category  687 non-null    object
# dtypes: Int64(2), object(7)
# memory usage: 50.8+ KB
# S. No                   201
# Incident Location       512
# District                357
# State/UT                 29
# Date of incident        145
# No. of deaths            14
# Reason of death         348
# Name(s) and age         638
# Occupation\nCategory    190
# ...

# %%
# 5.set index
df = df.set_index('State/UT')
df
# Out:
#                    S. No                     Incident Location      District  \
# State/UT
# Uttar Pradesh          1                                  Agra          Agra
# Gujarat                2                             Pandesara         Surat
# Rajasthan              3                                Jaipur        Jaipur
# Telangana              4                          Secunderabad  Secunderabad
# Jammu and Kashmir      5  Mountainous peak over Jawahar Tunnel      Anantnag
# ...                  ...                                   ...           ...
# Chhattisgarh          35                               Kalenda    Mahasamund
# Chhattisgarh          36                            Gohrapadar     Gariaband
# Odisha                37                            Jayarampur      Balasore
# Uttarakhand           38                              Dehradun      Dehradun
# Chhattisgarh          39                                   NaN           NaN
#
# ...

# %%
# 6.sort values
df = df.sort_index()
df
# Out:
#                 S. No     Incident Location                      District  \
# State/UT
#  Delhi             14                 Delhi                         Delhi
# Andhra Pradesh     28    different villages                    Sangareddy
# Andhra Pradesh     15              Dundigal                      Hyderbad
# Andhra Pradesh      3      Chodavaram Block                 Visakhapatnam
# Andhra Pradesh     15    Mittapalle village                      Chittoor
# ...               ...                   ...                           ...
# West Bengal       187  Regent Park, Kolkata                       Kolkata
# West Bengal        13              Talibpur                       Birbhum
# NaN                33     en route on train                           NaN
# NaN                34     en route on train                           NaN
# NaN              <NA>                   NaN  Deaths at Quarantine Centres
#
#                Date of incident  No. of deaths  \
# State/UT
# ...

# %%
# 7.checking duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [S. No, Incident Location, District, Date of incident, No. of deaths, Reason of death, Name(s) and age, Occupation
# Category]
# Index: []

# %%
# # .check for no duplicates
df.duplicated().sum()

df.isnull()
# Out:
# np.int64(0)

# %%
# 8.re-load into excel
# firstly import openpyxl module in environment of anaconda navigator
import openpyxl
# to excel
df.to_excel("non_virus_deaths_cleaned.xlsx", index=True)

# to csv
df.to_csv("non_virus_deaths_cleaned.csv", index=True)
