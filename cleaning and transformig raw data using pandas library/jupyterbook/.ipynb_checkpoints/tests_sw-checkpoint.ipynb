# %%
import pandas as pd

# %%
pd.read_csv("tests_state_wise.csv")
# Out:
#       Updated On                        State  Total Tested  \
# 0     17/04/2020  Andaman and Nicobar Islands        1403.0
# 1     24/04/2020  Andaman and Nicobar Islands        2679.0
# 2     27/04/2020  Andaman and Nicobar Islands        2848.0
# 3     01/05/2020  Andaman and Nicobar Islands        3754.0
# 4     16/05/2020  Andaman and Nicobar Islands        6677.0
# ...          ...                          ...           ...
# 3933  03/08/2020                  West Bengal      956659.0
# 3934  04/08/2020                  West Bengal      978980.0
# 3935  05/08/2020                  West Bengal     1003027.0
# 3936  06/08/2020                  West Bengal     1028251.0
# 3937  07/08/2020                  West Bengal           NaN
#
#      Tag (Total Tested)  Positive Negative  Unconfirmed  \
# 0          Samples Sent      12.0     1210        181.0
# 1          Samples Sent      27.0      NaN        246.0
# 2          Samples Sent      33.0      NaN        106.0
# ...

# %%
#1. check types and nulls
pd.read_csv("tests_state_wise.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3938 entries, 0 to 3937
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Updated On                             3938 non-null   object
#  1   State                                  3938 non-null   object
#  2   Total Tested                           3877 non-null   float64
#  3   Tag (Total Tested)                     3909 non-null   object
#  4   Positive                               3863 non-null   float64
#  5   Negative                               2517 non-null   object
#  6   Unconfirmed                            1719 non-null   float64
#  7   Cumulative People In Quarantine        276 non-null    float64
#  8   Total People Currently in Quarantine   1698 non-null   float64
#  9   Tag (People in Quarantine)             1719 non-null   object
# ...

# %%
# 2.remove duplicates nd check
df = pd.read_csv("tests_state_wise.csv")
df
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Updated On, State, Total Tested, Tag (Total Tested), Positive, Negative, Unconfirmed, Cumulative People In Quarantine, Total People Currently in Quarantine, Tag (People in Quarantine), Total People Released From Quarantine, People in ICU, People on Ventilators, Num Isolation Beds, Num ICU Beds, Num Ventilators, Total PPE, Total N95 Masks, Corona Enquiry Calls, Num Calls State Helpline, Source1, Source2, Source3, Test positivity rate, Tests per thousand, Tests per million, Tests per positive case, Population NCP 2019 Projection]
# Index: []
#
# [0 rows x 28 columns]

# %%
#3. change type of date to datetime
df = pd.read_csv("tests_state_wise.csv")
df['Updated On'] = pd.to_datetime(df['Updated On'],format='mixed')


df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3938 entries, 0 to 3937
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Updated On                             3938 non-null   datetime64[ns]
#  1   State                                  3938 non-null   object
#  2   Total Tested                           3877 non-null   float64
#  3   Tag (Total Tested)                     3909 non-null   object
#  4   Positive                               3863 non-null   float64
#  5   Negative                               2517 non-null   object
#  6   Unconfirmed                            1719 non-null   float64
#  7   Cumulative People In Quarantine        276 non-null    float64
#  8   Total People Currently in Quarantine   1698 non-null   float64
#  9   Tag (People in Quarantine)             1719 non-null   object
# ...

# %%
# 4.remove unwanted columns

df = df.drop(columns=['Tag (Total Tested)','Unconfirmed','Cumulative People In Quarantine','Total People Currently in Quarantine','Tag (People in Quarantine)','Total People Released From Quarantine','People in ICU','People on Ventilators','Num Isolation Beds','Num ICU Beds','Num Ventilators','Total PPE','Total N95 Masks','Corona Enquiry Calls','Num Calls State Helpline','Source1','Source2','Source3'])
df
# Out:
#      Updated On                        State  Total Tested  Positive Negative  \
# 0    2020-04-17  Andaman and Nicobar Islands        1403.0      12.0     1210
# 1    2020-04-24  Andaman and Nicobar Islands        2679.0      27.0      NaN
# 2    2020-04-27  Andaman and Nicobar Islands        2848.0      33.0      NaN
# 3    2020-01-05  Andaman and Nicobar Islands        3754.0      33.0      NaN
# 4    2020-05-16  Andaman and Nicobar Islands        6677.0      33.0      NaN
# ...         ...                          ...           ...       ...      ...
# 3933 2020-03-08                  West Bengal      956659.0   78232.0      NaN
# 3934 2020-04-08                  West Bengal      978980.0   80984.0      NaN
# 3935 2020-05-08                  West Bengal     1003027.0   83800.0      NaN
# 3936 2020-06-08                  West Bengal     1028251.0   86754.0      NaN
# 3937 2020-07-08                  West Bengal           NaN       NaN      NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3938 entries, 0 to 3937
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Updated On                      3938 non-null   datetime64[ns]
#  1   State                           3938 non-null   object
#  2   Total Tested                    3877 non-null   float64
#  3   Positive                        3863 non-null   float64
#  4   Negative                        2517 non-null   object
#  5   Test positivity rate            3592 non-null   object
#  6   Tests per thousand              3618 non-null   float64
#  7   Tests per million               3618 non-null   float64
#  8   Tests per positive case         3503 non-null   object
#  9   Population NCP 2019 Projection  3618 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(4)
# memory usage: 307.8+ KB
