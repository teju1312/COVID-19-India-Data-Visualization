# %%
import pandas as pd

# %%
pd.read_csv("oxygen_shortage_deaths_in_india.csv")
# Out:
#      s_no date_of_incident                                     hospital_place  \
# 0       1       03-05-2021  Chamarajanagar Institute of Medical Sciences (...
# 1       2       01-05-2021                       District Hospital in Barwani
# 2       3       01-05-2021                                     Batra Hospital
# 3       4       02-05-2021                            Nutema Hospital, Meerut
# 4       5       01-05-2021             Government General Hospital, Anantapur
# ..    ...              ...                                                ...
# 118   125      20-04-20121                          Meltron Covid Care Centre
# 119   126       21-04-2021  Swami Ramanand Teerth Rural Medical College, A...
# 120   127       24-04-2021                     Durgawati Hospital, Barhalganj
# 121   128       26-04-2021                               SNR district hopital
# 122   129       17-05-2021                   JVC medical college and hospital
#
# ...

# %%
# 1.check null and info
pd.read_csv("oxygen_shortage_deaths_in_india.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   s_no              123 non-null    int64
#  1   date_of_incident  121 non-null    object
#  2   hospital_place    123 non-null    object
#  3   district          122 non-null    object
#  4   state             123 non-null    object
#  5   no_of_deaths      123 non-null    int64
#  6   category          123 non-null    object
#  7   source            123 non-null    object
#  8   date_of_report    123 non-null    object
#  9   reference         123 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 9.7+ KB

# %%
# 2.remove unwanted columns
df = pd.read_csv("oxygen_shortage_deaths_in_india.csv")
df = df.drop(columns=['s_no','source','date_of_report','reference'])
df
# Out:
#     date_of_incident                                     hospital_place  \
# 0         03-05-2021  Chamarajanagar Institute of Medical Sciences (...
# 1         01-05-2021                       District Hospital in Barwani
# 2         01-05-2021                                     Batra Hospital
# 3         02-05-2021                            Nutema Hospital, Meerut
# 4         01-05-2021             Government General Hospital, Anantapur
# ..               ...                                                ...
# 118      20-04-20121                          Meltron Covid Care Centre
# 119       21-04-2021  Swami Ramanand Teerth Rural Medical College, A...
# 120       24-04-2021                     Durgawati Hospital, Barhalganj
# 121       26-04-2021                               SNR district hopital
# 122       17-05-2021                   JVC medical college and hospital
#
#            district              state  no_of_deaths         category
# ...

# %%
#3. check count of unique

df.nunique()
# Out:
# date_of_incident     35
# hospital_place      114
# district             89
# state                21
# no_of_deaths         19
# category              1
# dtype: int64

# %%
# 4.checking duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date_of_incident, hospital_place, district, state, no_of_deaths, category]
# Index: []

# %%
#5. setting index
df = df.set_index('state')
df
# Out:
#                   date_of_incident  \
# state
# Karnataka               03-05-2021
# Madhya Pradesh          01-05-2021
# Delhi                   01-05-2021
# Uttar Pradesh           02-05-2021
# Andhra Pradesh          01-05-2021
# ...                            ...
# Maharashtra            20-04-20121
# Maharashtra             21-04-2021
# Uttar Pradesh           24-04-2021
# Karnataka               26-04-2021
# Jammu and Kashmir       17-05-2021
#
#                                                       hospital_place  \
# state
# Karnataka          Chamarajanagar Institute of Medical Sciences (...
# Madhya Pradesh                          District Hospital in Barwani
# Delhi                                                 Batra Hospital
# Uttar Pradesh                                Nutema Hospital, Meerut
# Andhra Pradesh                Government General Hospital, Anantapur
# ...                                                              ...
# ...

# %%
# 6. sort values
df = df.sort_index()
df
# Out:
#                date_of_incident                              hospital_place  \
# state
# Andhra Pradesh       03-05-2021                  Hindupur District Hospital
# Andhra Pradesh       04-05-2021             Machilipatnam District Hospital
# Andhra Pradesh       05-05-2021                Private Hospital, Vijayawada
# Andhra Pradesh       04-05-2021  Anantapur Super Speciality Cancer Hospital
# Andhra Pradesh       27-04-2021               Proddatur Government Hospital
# ...                         ...                                         ...
# Uttar Pradesh        30-04-2021                                L-2 Hospital
# Uttar Pradesh        21-04-2021                           Almighty Hospital
# Uttar Pradesh        25-04-2021                            Narayan Hospital
# Uttarakhand          04-05-2021                                     Roorkee
# West Bengal          11-05-2021         Vidyasagar Hospital, Behala Kolkata
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 123 entries, Andhra Pradesh to West Bengal
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_of_incident  121 non-null    object
#  1   hospital_place    123 non-null    object
#  2   district          122 non-null    object
#  3   no_of_deaths      123 non-null    int64
#  4   category          123 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 5.8+ KB

# %%
# # .check for no duplicates
df.duplicated().sum()

df.isnull()
# Out:
# np.int64(0)

# %%
# 7.re-load into excel
# firstly import openpyxl module in environment of anaconda navigator
import openpyxl
# to excel
df.to_excel("oxy_shortage_deaths21_cleaned.xlsx", index=True)

# to csv
df.to_csv("oxy_shortage_deaths21_cleaned.csv", index=True)
