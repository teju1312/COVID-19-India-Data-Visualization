# %%
import pandas as pd

# %%
pd.read_csv("district-containment-zones-2020-04-30.csv")
# Out:
#      District ID             District Name                        State  \
# 0              1            South Andamans  Andaman And Nicobar lslands
# 1              2                  Nicobars  Andaman And Nicobar lslands
# 2              3  North And Middle Andaman  Andaman And Nicobar lslands
# 3              4                   Kurnool               Andhra Pradesh
# 4              5                    Guntur               Andhra Pradesh
# ..           ...                       ...                          ...
# 728          729                Coochbehar                  West Bengal
# 729          730          Dinajpur Dakshin                  West Bengal
# 730          731                   Purulia                  West Bengal
# 731          732                Alipurduar                  West Bensal
# 732          733                  Jhargram                  West Bengal
#
#     Classification
# 0         Red Zone
# 1       Green Zone
# 2       Green Zone
# 3         Red Zone
# ...

# %%
#1. check types and nulls
pd.read_csv("district-containment-zones-2020-04-30.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 733 entries, 0 to 732
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   District ID     733 non-null    int64
#  1   District Name   733 non-null    object
#  2   State           733 non-null    object
#  3   Classification  733 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 23.0+ KB

# %%
#2. check count of unique
df = pd.read_csv("district-containment-zones-2020-04-30.csv")
df.nunique()
# Out:
# District ID       731
# District Name     729
# State              45
# Classification      3
# dtype: int64

# %%
# 3.checking duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [District ID, District Name, State, Classification]
# Index: []

# %%
#4. setting index
df = df.set_index('District ID')
df
# Out:
#                         District Name                        State  \
# District ID
# 1                      South Andamans  Andaman And Nicobar lslands
# 2                            Nicobars  Andaman And Nicobar lslands
# 3            North And Middle Andaman  Andaman And Nicobar lslands
# 4                             Kurnool               Andhra Pradesh
# 5                              Guntur               Andhra Pradesh
# ...                               ...                          ...
# 729                        Coochbehar                  West Bengal
# 730                  Dinajpur Dakshin                  West Bengal
# 731                           Purulia                  West Bengal
# 732                        Alipurduar                  West Bensal
# 733                          Jhargram                  West Bengal
#
#             Classification
# District ID
# 1                 Red Zone
# 2               Green Zone
# 3               Green Zone
# ...

# %%
# 5. sort values
df = df.sort_index()
df
# Out:
#                         District Name                        State  \
# District ID
# 1                      South Andamans  Andaman And Nicobar lslands
# 2                            Nicobars  Andaman And Nicobar lslands
# 3            North And Middle Andaman  Andaman And Nicobar lslands
# 4                             Kurnool               Andhra Pradesh
# 5                              Guntur               Andhra Pradesh
# ...                               ...                          ...
# 729                        Coochbehar                  West Bengal
# 730                  Dinajpur Dakshin                  West Bengal
# 731                           Purulia                  West Bengal
# 732                        Alipurduar                  West Bensal
# 733                          Jhargram                  West Bengal
#
#             Classification
# District ID
# 1                 Red Zone
# 2               Green Zone
# 3               Green Zone
# ...

# %%
# # .check for no duplicates
df.duplicated().sum()

df.isnull()
# Out:
#              District Name  State  Classification
# District ID
# 1                    False  False           False
# 2                    False  False           False
# 3                    False  False           False
# 4                    False  False           False
# 5                    False  False           False
# ...                    ...    ...             ...
# 729                  False  False           False
# 730                  False  False           False
# 731                  False  False           False
# 732                  False  False           False
# 733                  False  False           False
#
# [733 rows x 3 columns]

# %%
# 6.re-load into excel
# firstly import openpyxl module in environment of anaconda navigator
import openpyxl
# to excel
df.to_excel("dist_zones_2020_cleaned.xlsx", index=True)

# to csv
df.to_csv("dist_zones_2020_cleaned.csv", index=True)
